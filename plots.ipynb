# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#                                  Neighborhood  Zip Code  Walkability Score  \
# 0  Forest Hills–71st Avenue (Queens terminal)     11375                 92
# 1         67th Avenue (Forest Hills / Queens)     11375                 95
# 2                        63rd Drive–Rego Park     11374                 89
# 3                         Woodhaven Boulevard     11421                 81
# 4                        Grand Avenue–Newtown     11373                 90
#
#   Niche Ranking  Avg Age Avg Household Income
# 0           #45     44.5             $104,319
# 1           #45     44.5             $104,319
# 2           #49     42.4              $86,333
# 3          #158     39.0              $89,429
# 4           NaN     38.3              $71,470

# %%
df = pd.read_csv("datatable.csv")

plt.scatter(df["Avg Household Income"], df["Niche Ranking"])
plt.xlabel("Average Household Income")
plt.ylabel("Niche Ranking")
plt.title("Average Household Income vs Niche Score")

plt.show()

# %%
import matplotlib.pyplot as plt


plt.bar(df["Station"], df["Niche Ranking"])
plt.xticks(rotation=90)
plt.xlabel("Neighborhood")
plt.ylabel("Niche Ranking")
plt.title("Niche Ranking by Neighborhood")
plt.show()

# %%
plt.scatter(df["Avg Age"], df["Niche Ranking"])
plt.xlabel("Average Age")
plt.ylabel("Niche Ranking")
plt.title("Average Age vs Niche Ranking")
plt.show()
